# %% [markdown]
# ## **BELLABEAT CASE STUDY | DATA ANALYSIS**
#
# Bellabeat, a leading high tech manufacturer of health-oriented products tailored for women, aims to establish itself as a major player in the global market for smart devices. Despite its current success, the company's founders believe that delving into the analysis of fitness data from smart devices could uncover fresh avenues for growth and expansion.
#
# In this study, I'll walk through the six stages of the data analysis process: **Ask**, **Prepare**, **Process**, **Analyze**, **Share**, and **Act**. By applying these steps, I'll dissect my analysis of the FitBit Fitness Tracker Data, aiming to uncover valuable insights that could prove advantageous for Bellabeat.
#
# **1.ASK**
#
# **1.1** **Business Task**
#
# Bellabeat is seeking to explore avenues for business expansion. To achieve this goal, I'll be examining data pertaining to the company's current user base utilizing its range of products, particularly smart devices. The objective is to identify patterns within the data and offer actionable recommendations that could unlock fresh growth opportunities for the company.
#
# **1.2** **Key Stakeholders**
#
# * **Urška Sršen:** Co-founder and Chief Creative Officer of Bellabeat.
# * **Sando Mur:** Co-founder of Bellabeat, renowned mathematician and a key member of the Bellabeat executive team.
# * Marketing Analytics Team at Bellabeat.
#
# **2.PREPARE**
#
# The dataset utilized in this case study is publicly available, making it accessible to all. Moreover, it originates from FitBit Fitness Tracker, a reputable source. These factors contribute to the credibility of the data. One can access it through here [link](https://www.kaggle.com/datasets/arashnic/fitbit).
# I will set up the environment by importing the necessary libraries for the analysis.

# %%
#importing the libraries
import numpy as np
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# In the downloaded data folder there are 18 CSV files. Each of them shows data related to the different functions of the device: calories, activity level, daily steps, sleep, distance, etc.
#
# **3.PROCESS**
#
# We'll load the Fitbit datasets we're interested in exploring for insights

# %%
#Importing the data
sleep_day=pd.read_csv("sleepDay_merged.csv")
weight_log=pd.read_csv("weightLogInfo_merged.csv")
daily_steps=pd.read_csv("dailySteps_merged.csv")
heart_rate=pd.read_csv("heartrate_seconds_merged.csv")
daily_intesity=pd.read_csv("dailyIntensities_merged.csv")
hourly_steps=pd.read_csv("hourlySteps_merged.csv")
daily_activity=pd.read_csv("dailyActivity_merged.csv")
daily_calories=pd.read_csv("dailyCalories_merged.csv")
hourly_calories=pd.read_csv("hourlyCalories_merged.csv")

# %% [markdown]
# **3.1 Data Exploration**
#
# We'll start by getting to know the information of our datasets hold.

# %%
display(sleep_day.head())
print(sleep_day.info(),"\n")
print(f"sleep day shape:{sleep_day.shape}")
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    object
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
# ...

# %%
display(weight_log.head())
print(weight_log.info(),"\n")
print(f"weight log shape:{weight_log.shape}")
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     object
# ...

# %%
display(daily_steps.head())
print(daily_steps.info(),"\n")
print(f"daily steps shape:{daily_steps.shape}")
# Out:
#            Id ActivityDay  StepTotal
# 0  1503960366   4/12/2016      13162
# 1  1503960366   4/13/2016      10735
# 2  1503960366   4/14/2016      10460
# 3  1503960366   4/15/2016       9762
# 4  1503960366   4/16/2016      12669
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           940 non-null    int64
#  1   ActivityDay  940 non-null    object
#  2   StepTotal    940 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 22.2+ KB
# None
#
# daily steps shape:(940, 3)

# %%
display(heart_rate.head())
print(heart_rate.info(),"\n")
print(f"heart rate shape:{heart_rate.shape}")
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    object
#  2   Value   int64
# dtypes: int64(2), object(1)
# memory usage: 56.8+ MB
# None
#
# heart rate shape:(2483658, 3)

# %%
display(daily_intesity.head())
print(daily_intesity.info(),"\n")
print(f"daily intesity shape:{daily_intesity.shape}")
# Out:
#            Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0  1503960366   4/12/2016               728                   328
# 1  1503960366   4/13/2016               776                   217
# 2  1503960366   4/14/2016              1218                   181
# 3  1503960366   4/15/2016               726                   209
# 4  1503960366   4/16/2016               773                   221
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   19                 21                      0.0
# 2                   11                 30                      0.0
# 3                   34                 29                      0.0
# 4                   10                 36                      0.0
#
#    LightActiveDistance  ModeratelyActiveDistance  VeryActiveDistance
# 0                 6.06                      0.55                1.88
# ...

# %%
display(hourly_steps.head())
print(hourly_steps.info(),"\n")
print(f"hourly steps shape:{hourly_steps.shape}")
# Out:
#            Id           ActivityHour  StepTotal
# 0  1503960366  4/12/2016 12:00:00 AM        373
# 1  1503960366   4/12/2016 1:00:00 AM        160
# 2  1503960366   4/12/2016 2:00:00 AM        151
# 3  1503960366   4/12/2016 3:00:00 AM          0
# 4  1503960366   4/12/2016 4:00:00 AM          0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22099 entries, 0 to 22098
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            22099 non-null  int64
#  1   ActivityHour  22099 non-null  object
#  2   StepTotal     22099 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 518.1+ KB
# None
#
# hourly steps shape:(22099, 3)

# %%
display(daily_activity.head())
print(daily_activity.info(),"\n")
print(f"daily activity shape:{daily_activity.shape}")
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
display(daily_calories.head())
print(daily_calories.info(),"\n")
print(f"daily calories shape:{daily_calories.shape}")
# Out:
#            Id ActivityDay  Calories
# 0  1503960366   4/12/2016      1985
# 1  1503960366   4/13/2016      1797
# 2  1503960366   4/14/2016      1776
# 3  1503960366   4/15/2016      1745
# 4  1503960366   4/16/2016      1863
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           940 non-null    int64
#  1   ActivityDay  940 non-null    object
#  2   Calories     940 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 22.2+ KB
# None
#
# daily calories shape:(940, 3)

# %%
display(hourly_calories.head())
print(hourly_calories.info(),"\n")
print(f"hourly calories shape:{hourly_calories.shape}")
# Out:
#            Id           ActivityHour  Calories
# 0  1503960366  4/12/2016 12:00:00 AM        81
# 1  1503960366   4/12/2016 1:00:00 AM        61
# 2  1503960366   4/12/2016 2:00:00 AM        59
# 3  1503960366   4/12/2016 3:00:00 AM        47
# 4  1503960366   4/12/2016 4:00:00 AM        48
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22099 entries, 0 to 22098
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            22099 non-null  int64
#  1   ActivityHour  22099 non-null  object
#  2   Calories      22099 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 518.1+ KB
# None
#
# hourly calories shape:(22099, 3)

# %% [markdown]
# Upon viewing the datasets, we notice:
# * **daily_intesity,daily_calories & daily_steps** datasets all have the columns that are in the daily_activity dataset.
# * **hourly_steps** & **hourly_calories** have the identical columns
# * **sleepday** column in sleep_day dataset is an object instead of datetime,same goes for the *activityhour* column in the **hourly_calories** and hourly_steps datasets plus activitydate column in the daily_activity dataset
# * Concerning data types, the columns *ActivityDate* in **daily_activity**, *ActivityHour* in **hourly_steps**, *ActivityHour* in **hourly_calories**, and *SleepDay* in **sleepday** are currently represented as objects instead of datetime data types. To facilitate smoother processing, we'll need to convert them into datetime data types.
# *Based on their shapes, I noticed that both **hourly_steps** and **hourly_calories** exhibit comparable structures, each with shape of (22099, 3) i.e 3 columns and 22099 rows. Consequently, we can opt to merge these datasets for subsequent analysis.

# %% [markdown]
# Moving forward, let's determine the number of distinct users present in each dataset.

# %%
#Getting to know how many users are in each dataset
print(f"Number of users in sleep_day dataset: {sleep_day["Id"].nunique()}","\n")
print(f"Number of users in weight_log dataset: {weight_log["Id"].nunique()}","\n")
print(f"Number of users in daily_steps dataset: {daily_steps["Id"].nunique()}","\n")
print(f"Number of users in heart_rate dataset: {heart_rate["Id"].nunique()}","\n")
print(f"Number of users in daily_intesity dataset: {daily_intesity["Id"].nunique()}","\n")
print(f"Number of users in hourly_steps dataset: {hourly_steps["Id"].nunique()}","\n")
print(f"Number of users in daily_activity dataset: {daily_activity["Id"].nunique()}","\n")
print(f"Number of users in daily_calories dataset: {daily_calories["Id"].nunique()}","\n")
print(f"Number of users in hourly_calories dataset: {hourly_calories["Id"].nunique()}","\n")
# Out:
# Number of users in sleep_day dataset: 24
#
# Number of users in weight_log dataset: 8
#
# Number of users in daily_steps dataset: 33
#
# Number of users in heart_rate dataset: 14
#
# Number of users in daily_intesity dataset: 33
#
# Number of users in hourly_steps dataset: 33
#
# Number of users in daily_activity dataset: 33
#
# Number of users in daily_calories dataset: 33
#
# Number of users in hourly_calories dataset: 33

# %% [markdown]
# We notice that among the datasets we examined, **heartrate_secs, weight_logged**, and **sleepday** did not meet our criterion of having at least 30 observations. Specifically, **heartrate_secs** has n=14, and **weight_logged** has n=8, thus we have decided to remove both of them. Although **sleepday** has n=24, which is also below our threshold, we have opted to retain it as it may still provide valuable insights.

# %% [markdown]
# * Lets change for any missing values and duplicates in our datasets before we can begin data transformation

# %%
#checking for missing values
print(f"Number of missing values in sleep_day:{sleep_day.isna().sum()}","\n")
print(f"Number of missing values in daily_steps:{daily_steps.isna().sum()}","\n")
print(f"Number of missing values in daily_intesity:{daily_intesity.isna().sum()}","\n")
print(f"Number of missing values in hourly_steps:{hourly_steps.isna().sum()}","\n")
print(f"Number of missing values in daily_activity:{daily_activity.isna().sum()}","\n")
print(f"Number of missing values in daily_calories:{daily_calories.isna().sum()}","\n")
print(f"Number of missing values in hourly_calories:{hourly_calories.isna().sum()}","\n")
# Out:
# Number of missing values in sleep_day:Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64
#
# Number of missing values in daily_steps:Id             0
# ActivityDay    0
# StepTotal      0
# dtype: int64
#
# Number of missing values in daily_intesity:Id                          0
# ActivityDay                 0
# SedentaryMinutes            0
# LightlyActiveMinutes        0
# FairlyActiveMinutes         0
# VeryActiveMinutes           0
# SedentaryActiveDistance     0
# LightActiveDistance         0
# ModeratelyActiveDistance    0
# VeryActiveDistance          0
# dtype: int64
#
# Number of missing values in hourly_steps:Id              0
# ActivityHour    0
# StepTotal       0
# dtype: int64
#
# Number of missing values in daily_activity:Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# ...

# %%
#check for duplicates
print(f"Duplicates present in sleep_day dataset: {sleep_day.duplicated().any()}","\n")
print(f"Duplicates present in daily_steps dataset: {daily_steps.duplicated().any()}","\n")
print(f"Duplicates present in daily_intensity dataset: {daily_intesity.duplicated().any()}","\n")
print(f"Duplicates present in hourly_steps dataset: {hourly_steps.duplicated().any()}","\n")
print(f"Duplicates present in daily_activity dataset: {daily_activity.duplicated().any()}","\n")
print(f"Duplicates present in daily_calories dataset: {daily_calories.duplicated().any()}","\n")
print(f"Duplicates present in hourly_calories dataset: {hourly_calories.duplicated().any()}","\n")
# Out:
# Duplicates present in sleep_day dataset: True
#
# Duplicates present in daily_steps dataset: False
#
# Duplicates present in daily_intensity dataset: False
#
# Duplicates present in hourly_steps dataset: False
#
# Duplicates present in daily_activity dataset: False
#
# Duplicates present in daily_calories dataset: False
#
# Duplicates present in hourly_calories dataset: False

# %% [markdown]
# There were no missing values in the datasets however in the sleep_day dataset I was able to find three duplicates and I had to remove them

# %%
#found duplicates in the sleep_day dataset,we have to drop them
sleep_day.drop_duplicates(inplace=True)

# %% [markdown]
# **3.2 Data transformation**
#
# Let's start by converting the *ActivityDate* in **daily_activity**, *ActivityHour* in **hourly_steps**, *ActivityHour* in **hourly_calories**, and *SleepDay* in **sleepday** to datetime data type.

# %%
# Parse dates with specified formats
sleep_day["SleepDay"] = pd.to_datetime(sleep_day["SleepDay"], format="%m/%d/%Y %I:%M:%S %p") 
hourly_steps["ActivityHour"] = pd.to_datetime(hourly_steps["ActivityHour"], format="%m/%d/%Y %I:%M:%S %p")
daily_activity["ActivityDate"] = pd.to_datetime(daily_activity["ActivityDate"], format="%m/%d/%Y")
hourly_calories["ActivityHour"] = pd.to_datetime(hourly_calories["ActivityHour"], format="%m/%d/%Y %I:%M:%S %p")

# %% [markdown]
# Remember that both **hourly_steps** and **hourly_calories** exhibit comparable structures, each with shape of (22099, 3) i.e 3 columns and 22099 rows, so we are going to merge them. The both share the Id and ActivityHour columns so we'll perform an inner join.

# %%
#merge hourly_steps and hourly_calories
hourly_merged=hourly_calories.merge(hourly_steps, on=["Id","ActivityHour"],how="inner")
hourly_merged.head(5)
# Out:
#            Id        ActivityHour  Calories  StepTotal
# 0  1503960366 2016-04-12 00:00:00        81        373
# 1  1503960366 2016-04-12 01:00:00        61        160
# 2  1503960366 2016-04-12 02:00:00        59        151
# 3  1503960366 2016-04-12 03:00:00        47          0
# 4  1503960366 2016-04-12 04:00:00        48          0

# %% [markdown]
# For us to know if there are in relationship with the days and the activities, we need to create new columns of days and hours.
# Let's create a new column **(Hours)** and **(ActivityDate)** in the hourly_merged dataset and new column **ActivityDate** in the **daily_activity** dataset. After creating the new columns I had to change to their correct data types

# %%
#getting the hours
hourly_merged["Hour"]=hourly_merged["ActivityHour"].dt.hour
#getting the dates
hourly_merged["ActivityDate"]=hourly_merged["ActivityHour"].dt.date
# change to datetime data type
hourly_merged["ActivityDate"]=pd.to_datetime(hourly_merged["ActivityDate"])

# %% [markdown]
# Moreover lets create a new column for our days from the **sleep_day, hourly_merged** and **daily_activity** datasets. We'll then drop the ActivityHour column since we don't need it.

# %%
# get the days of the week in a new column
hourly_merged["Day"]=hourly_merged["ActivityDate"].dt.day_name()
# get the days of the week in a new column
sleep_day["Day"]=sleep_day["SleepDay"].dt.day_name()
# get the days of the week in a new column
daily_activity["Day"]=daily_activity["ActivityDate"].dt.day_name()
#drop the activityhour column since we don't need it
hourly_merged.drop(columns="ActivityHour",axis=1,inplace=True)

# %% [markdown]
# You may observe that our recently merged dataframe and the **sleep_day** dataframe share identical columns. Consequently, we'll combine them. Prior to this, let's modify the column name **SleepDay** in the sleep_day dataframe to align it with the **ActivityDay** column in the **hourly_merged** dataframe.

# %%
#re naming the column
sleep_day = sleep_day.rename(columns={"SleepDay": "ActivityDate"})
#merging the dataframes
df_merged =hourly_merged.merge(sleep_day, on=["Id","ActivityDate","Day"], how="inner")

# %% [markdown]
# Then we'll make sure the newly merged dataframe is clean

# %%
#check if the new dataframe is clean
display(df_merged.head())
print(f"Missing values present: {df_merged.isna().any()}","\n") 
print(f"Duplicates present: {df_merged.duplicated().any()}","\n") 
print(f"Number of users: {df_merged["Id"].nunique()}","\n")
# Out:
#            Id  Calories  StepTotal  Hour ActivityDate      Day  \
# 0  1503960366        81        373     0   2016-04-12  Tuesday
# 1  1503960366        61        160     1   2016-04-12  Tuesday
# 2  1503960366        59        151     2   2016-04-12  Tuesday
# 3  1503960366        47          0     3   2016-04-12  Tuesday
# 4  1503960366        48          0     4   2016-04-12  Tuesday
#
#    TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# 0                  1                 327             346
# 1                  1                 327             346
# 2                  1                 327             346
# 3                  1                 327             346
# 4                  1                 327             346
# Missing values present: Id                    False
# Calories              False
# StepTotal             False
# Hour                  False
# ActivityDate          False
# Day                   False
# TotalSleepRecords     False
# ...

# %% [markdown]
# We'll now proceed to make adjustments to the **daily_activity** dataframe. Initially, we'll introduce two new columns, namely **TotalActiveMinutes** and **TotalMinutes**, alongside **TotalActiveHours.** Following this, we'll proceed to eliminate unnecessary columns.

# %%
#create new columns TotalActiveMinutes, TotalMinutes and TotalActive hours
daily_activity["TotalActiveMinutes"]=daily_activity["VeryActiveMinutes"] + daily_activity["FairlyActiveMinutes"] + daily_activity["LightlyActiveMinutes"]
daily_activity["TotalMinutes"] = daily_activity["TotalActiveMinutes"] + daily_activity["SedentaryMinutes"]
daily_activity["TotalActiveHours"] = round(daily_activity["TotalActiveMinutes"] / 60)
daily_activity["TotalDistance"]=daily_activity["VeryActiveDistance"] + daily_activity["LightActiveDistance"] + daily_activity["ModeratelyActiveDistance"]
display(daily_activity.head())
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-04-12       13162           8.49             8.50
# 1  1503960366   2016-04-13       10735           6.97             6.97
# 2  1503960366   2016-04-14       10460           6.75             6.74
# 3  1503960366   2016-04-15        9762           6.23             6.28
# 4  1503960366   2016-04-16       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %% [markdown]
# **4.ANALYZE**
#
# With our data processed, it's now opportune to delve into analysis for insights. We've streamlined our datasets to three distinct dataframes: **daily_activity, merge_df** and **merge_df2.** Consequently, we'll derive insights from these dataframes. To commence, let's obtain statistical information about each of them.

# %%
summary=daily_activity[["TotalSteps","TotalDistance","Calories","TotalActiveMinutes","TotalMinutes","TotalActiveHours","SedentaryMinutes"]].describe()
summary1=df_merged[["Calories","StepTotal","Hour","TotalMinutesAsleep","TotalTimeInBed"]].describe()
summary2=hourly_merged[["Calories","StepTotal","Hour"]].describe()
display(summary)
display(summary1)
display(summary2)
# Out:
#          TotalSteps  TotalDistance     Calories  TotalActiveMinutes  \
# count    940.000000     940.000000   940.000000          940.000000
# mean    7637.910638       5.411043  2303.609574          227.542553
# std     5087.150742       3.935796   718.166862          121.776307
# min        0.000000       0.000000     0.000000            0.000000
# 25%     3789.750000       2.540000  1828.500000          146.750000
# 50%     7405.500000       5.175000  2134.000000          247.000000
# 75%    10727.000000       7.637500  2793.250000          317.250000
# max    36019.000000      28.020000  4900.000000          552.000000
#
#        TotalMinutes  TotalActiveHours  SedentaryMinutes
# count    940.000000        940.000000        940.000000
# mean    1218.753191          3.775532        991.210638
# std      265.931767          2.057646        301.267437
# min        2.000000          0.000000          0.000000
# 25%      989.750000          2.000000        729.750000
# ...

# %% [markdown]
# Lets look at the correlation of **hourly_merged** and **daily_activity**

# %%
corr = hourly_merged[["Calories", "Hour"]].corr()
corr1 = daily_activity[["TotalSteps", "TotalDistance", "Calories", "SedentaryMinutes"]].corr()

fig, ax = plt.subplots(1, 2, figsize=(14, 6)) 
#lets plot the heatmap for hourly_merged data
sns.heatmap(corr, ax=ax[0], annot=True, cmap="coolwarm", vmin=-1, vmax=1, linewidths=0.5, linecolor="black")
ax[0].set_title("Correlation Heatmap: Hourly Data", fontsize=12, fontweight="bold")
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45, ha="right", fontsize=10)
ax[0].set_yticklabels(ax[0].get_yticklabels(), rotation=45, fontsize=10)

#lets plot the heatmap for daily_activity
sns.heatmap(corr1, ax=ax[1], annot=True, cmap="coolwarm", vmin=-1, vmax=1, linewidths=0.5, linecolor="black")
ax[1].set_title("Correlation Heatmap: Daily Activity Data", fontsize=12, fontweight="bold")
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45, ha="right", fontsize=10)
ax[1].set_yticklabels(ax[1].get_yticklabels(), rotation=45, fontsize=10)

plt.tight_layout() 
plt.show()

# %% [markdown]
# Here are some noteworthy discoveries:
#
# * There's a discernible positive correlation between steps taken and calories burned.
# * Out of a total of 1218 minutes, 991 minutes were spent in a sedentary state, while approximately 228 minutes were active.
# * On average, users took 7638 steps daily, and the daily calorie burn averaged 2304.
# * However there's a negative correlation between Sedentary Minutes and Calories which makes sense cause you can't burn calories while at rest.

# %% [markdown]
# **5.SHARE**

# %% [markdown]
# Visualizing data provides a clear and detailed view of our information. Let's create visualizations to support and strengthen our findings from the analysis phase.

# %% [markdown]
#   Lets visualize Total steps with Calories burnt

# %%
plt.figure(figsize=(10, 7)) 
sns.scatterplot(
    x="Calories",
    y="TotalSteps",
    data=daily_activity,
    color="steelblue",
    s=70,
    edgecolor="black"
)
plt.xlabel("Calories Burnt", fontsize=10, fontweight="bold")
plt.ylabel("Total Steps Covered", fontsize=10, fontweight="bold")
plt.title("Scatter Plot: Calories Burnt vs Total Steps Covered", fontsize=12, fontweight="bold")
plt.grid(True, linestyle="solid")
plt.show()

# %% [markdown]
# Lets visualize Calories burnt while at rest

# %%
#lets plot our scatterplot
plt.figure(figsize=(10, 7))
sns.scatterplot(
    x="Calories",
    y="SedentaryMinutes",
    data=daily_activity, 
    color="slategray",
    s=70, 
    edgecolor="black"
)
plt.xlabel("Calories Burnt", fontsize=10, fontweight="bold")
plt.ylabel("Sedentary Minutes", fontsize=10, fontweight="bold")
plt.title("Calories Burnt at Rest vs Sedentary Minutes", fontsize=12, fontweight="bold")
plt.grid(True, linestyle="solid")
plt.show()

# %% [markdown]
# * These two scatterplots offer a clearer depiction of the relationship between TotalSteps and SedentaryMinutes with respect to Calories. As the number of steps taken increases, so does the calorie expenditure. Conversely, higher levels of sedentary minutes correlate with lower calorie burn.

# %% [markdown]
# Lets visualize the active and sedentary minutes

# %%
#lets plot the active and sedentary minutes
mean_minutes = daily_activity[["SedentaryMinutes", "TotalActiveMinutes"]].mean()
mean_minutes.plot(figsize=(10, 7), kind="bar", color="steelblue", edgecolor="black",rot=0)
plt.ylabel("Mean Minutes", fontsize=10, fontweight="bold")
plt.title("Comparison of Sedentary Minutes vs Total Active Minutes", fontsize=12, fontweight="bold")
plt.grid(True, axis="y",linestyle="solid")
plt.show()

# %% [markdown]
# * There's a substantial disparity between SedentaryMinutes and TotalActiveMinutes. It's apparent that users spend significantly more time in sedentary positions compared to being actively engaged.

# %% [markdown]
# Lets vizualise distribution of distances by activity level

# %%
summary_df = daily_activity[["VeryActiveDistance", "ModeratelyActiveDistance", "LightActiveDistance", "SedentaryActiveDistance"]].sum()
colors = sns.color_palette("pastel")
plt.figure(figsize=(10, 7))
plt.pie(
    summary_df,
    labels=summary_df.index,
    autopct="%1.0f%%",
    startangle=0,
    colors=colors, 
    shadow=False,
    explode=(0.1, 0.05, 0.05, 0.05),
    wedgeprops={"edgecolor": "black"} 
)
plt.title("Proportion of Intensity of Exercise Activity")
plt.axis("equal")
plt.show()

# %% [markdown]
# * The chart depicts that users exercise shorter distances when they are active compared to when they are less exercise distance when active. Furthermore, during periods of rest or relaxation, they cover no distance at all.

# %% [markdown]
# Lets visualize and see the most and least active hours throughout the day

# %%
#lets plot our bar plot
plt.figure(figsize=(10, 7)) 
hourly_mean_steps = hourly_merged.groupby(hourly_merged["Hour"])["StepTotal"].mean()
hourly_mean_steps_sorted = hourly_mean_steps.sort_values(ascending=False)
hourly_mean_steps_sorted.plot(kind="bar", color="steelblue", edgecolor= "black",rot=0)
plt.xlabel("Hour of the Day", fontsize=10, fontweight="bold")
plt.ylabel("Average Total Steps", fontsize=10, fontweight="bold")
plt.title("Average Steps Taken During Each Hour of the Day", fontsize=12, fontweight="bold")
plt.grid(True, axis="y", linestyle="solid")
plt.tight_layout() 
plt.show()

# %% [markdown]
# Indeed the users are we observe that their day becomes increasingly hectic starting from 8 a.m. until 7 p.m. The least active hours span from 8 p.m. to 10 p.m. These hours likely present optimal opportunities for targeted ad campaigns to reach them effectively.

# %% [markdown]
# Lets look at calories burnt by the number of days in a weeek

# %%
#lets look at the distribution of the calories burned 
plt.figure(figsize=(10, 7))
daily_calories = hourly_merged.groupby("Day")["Calories"].sum()
daily_calories_sorted =daily_calories.sort_values(ascending=False)
plt.bar(daily_calories_sorted.index, daily_calories_sorted.values, color="slategray", edgecolor="black")
for index, value in enumerate(daily_calories_sorted.values):
    plt.text(index, value + 10, f"{value:.0f}", ha="center", fontsize=10)
plt.title("Calories Burnt During Rest by Day", fontsize=14, fontweight='bold')
plt.xlabel("Days", fontsize=12, fontweight='bold')
plt.ylabel("Total Calories Burned", fontsize=12, fontweight="bold")
plt.xticks(rotation=45)
plt.grid(True, axis="y", linestyle="solid")
plt.tight_layout()

# %% [markdown]
# * The graph illustrates that the highest calorie expenditure occurred on Saturday, while the lowest occurred on Monday. It's understandable that Saturday, being a weekend, offers users ample time for exercise. However, the notably low calorie burn on Monday is somewhat unexpected, considering it's typically perceived as a busy workday for many individuals. One plausible explanation could be that users are heavily occupied at their desks on Mondays, leaving little time for exercise.

# %% [markdown]
# Lets look at the total steps covered in each day

# %%
#lets plot the bar plot of the total steps in each day
plt.figure(figsize=(10, 7))
steps_by_day = daily_activity.groupby("Day")["TotalSteps"].sum()
steps_by_day_sorted= steps_by_day.sort_values(ascending =False)
plt.bar(steps_by_day_sorted.index, steps_by_day_sorted.values, color="peru", edgecolor="black")
#lets add the value labels on top of each bar
for index, value in enumerate(steps_by_day_sorted.values):
    plt.text(index, value + 500, f"{value:.0f}", ha="center", fontsize=10)
plt.xlabel("Week Days", fontsize=12, fontweight="bold")
plt.ylabel("Total Steps Taken", fontsize=12, fontweight="bold")
plt.title("Total Steps Taken by Week Days", fontsize=14, fontweight="bold")
plt.xticks(rotation=45)
plt.grid(True, axis="y", linestyle="solid")
plt.tight_layout()
plt.show()

# %% [markdown]
# * We observe that fewer steps were taken by users on Monday compared to the rest of the week, indicating prolonged periods spent seated at work desks. This insight also hints at the user profile likely consisting of working-class individuals. Conversely, the highest step count occurred on Saturday and Sunday, which aligns with the expectations.

# %% [markdown]
# **6.ACT**
#
# * Daily steps contribute to calorie expenditure. Bellabeat may suggest a minimum step count tailored to users' goals to motivate goal achievement. According to the data, engaging in light to moderate exercise (less than 10,000 steps) appears to be most conducive to better sleep quality. Bellabeat could advocate for this level of physical activity for individuals seeking to maintain a healthy lifestyle, particularly those not involved in high-intensity sports.
# * Moreover,to expand their user base and attract more customers, the company should enhance its notification system and to foster a daily exercise habit, Bellabeat could schedule notifications at specific times, encouraging users to maintain consistency throughout the week.Additionally, Bellabeat could suggest health and fitness articles within its app as an effective means to inspire users.
# * Lastly, I suggest collecting additional information about the users beyond their activities and records. This could include details such as their profession, age, location, hobbies, and other relevant data. It's crucial to gather this information ethically and with user awareness. I believe that acquiring such data could enhance the analysis conducted by the market research team and provide valuable insights for the company to better understand its current users and expand its reach.
